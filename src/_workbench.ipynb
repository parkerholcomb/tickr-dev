# %%
# from tickr.stubhub import StubHubWrapper as sh

# events = sh.event_search(phrase="baseball")
# Out:
#    eventId                                         name  \
# 0  8779012  Sacramento River Cats at Round Rock Express
# 1  8779013  Sacramento River Cats at Round Rock Express
# 2  8779014  Sacramento River Cats at Round Rock Express
# 3  8779015  Sacramento River Cats at Round Rock Express
# 4  8779016  Sacramento River Cats at Round Rock Express
# 5  8779017  Sacramento River Cats at Round Rock Express
#
#                                                  url dayOfWeek formattedDate  \
# 0  /round-rock-express-round-rock-tickets-7-26-20...       Tue   Jul 26 2022
# 1  /round-rock-express-round-rock-tickets-7-27-20...       Wed   Jul 27 2022
# 2  /round-rock-express-round-rock-tickets-7-28-20...       Thu   Jul 28 2022
# 3  /round-rock-express-round-rock-tickets-7-29-20...       Fri   Jul 29 2022
# 4  /round-rock-express-round-rock-tickets-7-30-20...       Sat   Jul 30 2022
# 5  /round-rock-express-round-rock-tickets-7-31-20...       Sun   Jul 31 2022
#
# ...

# %%
tickets_search(endpoint = df['url'][1])
# Out:
# showing 20 924
#             id    eventId section  sectionId  sectionType row seatFrom seatTo  \
# 0   5388289284  150220714     217    1332364            2   M       12     15
# 1   5366778819  150220714     208    1332355            2   M        5      6
# 2   5388290274  150220714     217    1332364            2   P        1      6
# 3   5328954708  150220714     209    1332356            2   N       13     16
# 4   5283957338  150220714     208    1332355            2   L      NaN    NaN
# 5   5290140321  150220714     208    1332355            2   Q
# 6   5290140061  150220714     209    1332356            2   L
# 7   5309122412  150220714     208    1332355            2   Q        4      7
# 8   5365220690  150220714     218    1332365            2   K       23     26
# 9   5365225852  150220714     218    1332365            2   K        1      4
# 10  5369769232  150220714     218    1332365            2   K        5     10
# ...
