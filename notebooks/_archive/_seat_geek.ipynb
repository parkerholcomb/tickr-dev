# %%
import pandas as pd
import requests

sr

def event_search(performers_id = "1388", page_index = 1, per_page = 25) -> pd.DataFrame:
    params = {
        'page': str(page_index),
        'per_page': str(per_page),
        'performers.id': performers_id,
        'client_id': 'MTY2MnwxMzgzMzIwMTU4', # huh... guess this is where my location is
    }

    response = requests.get('https://seatgeek.com/api/events', params=params)
    data = response.json()
    data.keys()
    pd.options.display.max_columns = None
    df = pd.DataFrame(data['events'])
    return df

df = event_search()
df
# Out:
#        type       id         datetime_utc  \
# 0   concert  5719443  2022-09-09T00:00:00
# 1   concert  5719446  2022-09-11T00:00:00
# 2   concert  5719448  2022-09-12T00:00:00
# 3   concert  5719450  2022-09-14T00:00:00
# 4   concert  5719452  2022-09-15T00:00:00
# 5   concert  5719454  2022-09-17T00:00:00
# 6   concert  5719456  2022-09-18T00:00:00
# 7   concert  5759929  2022-09-19T00:00:00
# 8   concert  5719458  2022-09-20T23:00:00
# 9   concert  5719459  2022-09-21T23:00:00
# 10  concert  5719462  2022-09-23T23:00:00
# 11  concert  5719464  2022-09-25T23:00:00
# 12  concert  5719466  2022-09-27T23:00:00
# 13  concert  5719467  2022-09-28T23:00:00
# 14  concert  5719470  2022-09-30T23:00:00
# 15  concert  5719472  2022-10-01T23:00:00
# 16  concert  5719474  2022-10-02T23:00:00
# 17  concert  5719476  2022-10-04T23:00:00
# 18  concert  5719478  2022-10-05T23:00:00
# 19  concert  5719479  2022-10-07T23:00:00
# 20  concert  5719482  2022-10-09T00:00:00
# 21  concert  5719483  2022-10-10T00:00:00
# 22  concert  5719486  2022-10-12T01:00:00
# 23  concert  5719488  2022-10-14T01:00:00
# 24  concert  5719489  2022-10-16T02:00:00
#
#                                                 venue  datetime_tbd  \
# 0   {'state': 'TX', 'name_v2': 'Moody Center ATX',...         False
# 1   {'state': 'TX', 'name_v2': 'Toyota Center', 'p...         False
# 2   {'state': 'TX', 'name_v2': 'Dickies Arena', 'p...         False
# 3   {'state': 'MO', 'name_v2': 'T-Mobile Center', ...         False
# 4   {'state': 'MN', 'name_v2': 'Xcel Energy Center...         False
# 5   {'state': 'WI', 'name_v2': 'Fiserv Forum', 'po...         False
# 6   {'state': 'IL', 'name_v2': 'United Center', 'p...         False
# 7   {'state': 'IL', 'name_v2': 'United Center', 'p...         False
# 8   {'state': 'MI', 'name_v2': 'Little Caesars Are...         False
# 9   {'state': 'OH', 'name_v2': 'Nationwide Arena',...         False
# 10  {'state': 'NY', 'name_v2': 'Madison Square Gar...         False
# 11  {'state': 'ON', 'name_v2': 'Scotiabank Arena',...         False
# 12  {'state': 'QC', 'name_v2': 'Centre Bell', 'pos...         False
# 13  {'state': 'MA', 'name_v2': 'TD Garden', 'posta...         False
# 14  {'state': 'PA', 'name_v2': 'Wells Fargo Center...         False
# 15  {'state': 'DC', 'name_v2': 'Capital One Arena'...         False
# 16  {'state': 'NC', 'name_v2': 'PNC Arena', 'posta...         False
# 17  {'state': 'FL', 'name_v2': 'FLA Live Arena', '...         False
# 18  {'state': 'FL', 'name_v2': 'Amalie Arena', 'po...         False
# 19  {'state': 'GA', 'name_v2': 'Gas South Arena', ...         False
# 20  {'state': 'TN', 'name_v2': 'Bridgestone Arena'...         False
# 21  {'state': 'MO', 'name_v2': 'Enterprise Center'...         False
# 22  {'state': 'CO', 'name_v2': 'Ball Arena', 'post...         False
# 23  {'state': 'UT', 'name_v2': 'Vivint Arena', 'po...         False
# 24  {'state': 'OR', 'name_v2': 'Moda Center', 'pos...         False
#
#                                            performers  \
# 0   [{'type': 'band', 'name': 'Panic! At The Disco...
# 1   [{'type': 'band', 'name': 'Panic! At The Disco...
# 2   [{'type': 'band', 'name': 'Panic! At The Disco...
# 3   [{'type': 'band', 'name': 'Panic! At The Disco...
# 4   [{'type': 'band', 'name': 'Panic! At The Disco...
# 5   [{'type': 'band', 'name': 'Panic! At The Disco...
# 6   [{'type': 'band', 'name': 'Panic! At The Disco...
# 7   [{'type': 'band', 'name': 'Panic! At The Disco...
# 8   [{'type': 'band', 'name': 'Panic! At The Disco...
# 9   [{'type': 'band', 'name': 'Panic! At The Disco...
# 10  [{'type': 'band', 'name': 'Panic! At The Disco...
# 11  [{'type': 'band', 'name': 'Panic! At The Disco...
# 12  [{'type': 'band', 'name': 'Panic! At The Disco...
# 13  [{'type': 'band', 'name': 'Panic! At The Disco...
# 14  [{'type': 'band', 'name': 'Panic! At The Disco...
# 15  [{'type': 'band', 'name': 'Panic! At The Disco...
# 16  [{'type': 'band', 'name': 'Panic! At The Disco...
# 17  [{'type': 'band', 'name': 'Panic! At The Disco...
# 18  [{'type': 'band', 'name': 'Panic! At The Disco...
# 19  [{'type': 'band', 'name': 'Panic! At The Disco...
# 20  [{'type': 'band', 'name': 'Panic! At The Disco...
# 21  [{'type': 'band', 'name': 'Panic! At The Disco...
# 22  [{'type': 'band', 'name': 'Panic! At The Disco...
# 23  [{'type': 'band', 'name': 'Panic! At The Disco...
# 24  [{'type': 'band', 'name': 'Panic! At The Disco...
#
#                                          venue_config  is_open links  \
# 0   {'map_config_id': 10776, 'venue_id': 518721, '...    False    []
# 1   {'map_config_id': 6949, 'venue_id': 129, 'stat...    False    []
# 2   {'map_config_id': 10797, 'venue_id': 460055, '...    False    []
# 3   {'map_config_id': 3796, 'venue_id': 84, 'stati...    False    []
# 4   {'map_config_id': 7001, 'venue_id': 123, 'stat...    False    []
# 5   {'map_config_id': 6734, 'venue_id': 435592, 's...    False    []
# 6   {'map_config_id': 6110, 'venue_id': 136, 'stat...    False    []
# 7   {'map_config_id': 6110, 'venue_id': 136, 'stat...    False    []
# 8   {'map_config_id': 6138, 'venue_id': 420444, 's...    False    []
# 9   {'map_config_id': 10800, 'venue_id': 430, 'sta...    False    []
# 10  {'map_config_id': 10773, 'venue_id': 93, 'stat...    False    []
# 11  {'map_config_id': 3469, 'venue_id': 91, 'stati...    False    []
# 12  {'map_config_id': 6042, 'venue_id': 139, 'stat...    False    []
# 13  {'map_config_id': 4968, 'venue_id': 1544, 'sta...    False    []
# 14  {'map_config_id': 5948, 'venue_id': 3148, 'sta...    False    []
# 15  {'map_config_id': 5298, 'venue_id': 181, 'stat...    False    []
# 16  {'map_config_id': 6806, 'venue_id': 1430, 'sta...    False    []
# 17  {'map_config_id': 6109, 'venue_id': 126, 'stat...    False    []
# 18  {'map_config_id': 5207, 'venue_id': 182, 'stat...    False    []
# 19  {'map_config_id': 10803, 'venue_id': 110, 'sta...    False    []
# 20  {'map_config_id': 6394, 'venue_id': 2195, 'sta...    False    []
# 21  {'map_config_id': 7021, 'venue_id': 186, 'stat...    False    []
# 22  {'map_config_id': 10779, 'venue_id': 187, 'sta...    False    []
# 23  {'map_config_id': 10804, 'venue_id': 188, 'sta...    False    []
# 24  {'map_config_id': 4433, 'venue_id': 256, 'stat...    False    []
#
#          datetime_local  time_tbd  \
# 0   2022-09-08T19:00:00     False
# 1   2022-09-10T19:00:00     False
# 2   2022-09-11T19:00:00     False
# 3   2022-09-13T19:00:00     False
# 4   2022-09-14T19:00:00     False
# 5   2022-09-16T19:00:00     False
# 6   2022-09-17T19:00:00     False
# 7   2022-09-18T19:00:00     False
# 8   2022-09-20T19:00:00     False
# 9   2022-09-21T19:00:00     False
# 10  2022-09-23T19:00:00     False
# 11  2022-09-25T19:00:00     False
# 12  2022-09-27T19:00:00     False
# 13  2022-09-28T19:00:00     False
# 14  2022-09-30T19:00:00     False
# 15  2022-10-01T19:00:00     False
# 16  2022-10-02T19:00:00     False
# 17  2022-10-04T19:00:00     False
# 18  2022-10-05T19:00:00     False
# 19  2022-10-07T19:00:00     False
# 20  2022-10-08T19:00:00     False
# 21  2022-10-09T19:00:00     False
# 22  2022-10-11T19:00:00     False
# 23  2022-10-13T19:00:00     False
# 24  2022-10-15T19:00:00     False
#
#                                           short_title    visible_until_utc  \
# 0   Panic! At The Disco with Beach Bunny and Jake ...  2022-09-09T04:00:00
# 1   Panic! At The Disco with Beach Bunny and Jake ...  2022-09-11T04:00:00
# 2   Panic! At The Disco with Beach Bunny and Jake ...  2022-09-12T04:00:00
# 3   Panic! At The Disco with Beach Bunny and Jake ...  2022-09-14T04:00:00
# 4   Panic! At The Disco with Beach Bunny and Jake ...  2022-09-15T04:00:00
# 5   Panic! At The Disco with Marina and Jake Wesle...  2022-09-17T04:00:00
# 6   Panic! At The Disco with Marina and Jake Wesle...  2022-09-18T04:00:00
# 7                                 Panic! At The Disco  2022-09-19T04:00:00
# 8   Panic! At The Disco with Marina and Jake Wesle...  2022-09-21T03:00:00
# 9   Panic! At The Disco with Marina and Jake Wesle...  2022-09-22T03:00:00
# 10  Panic! At The Disco with Marina and Jake Wesle...  2022-09-24T03:00:00
# 11  Panic! At The Disco with Marina and Jake Wesle...  2022-09-26T03:00:00
# 12  Panic! At The Disco with Marina and Jake Wesle...  2022-09-28T03:00:00
# 13  Panic! At The Disco with Marina and Jake Wesle...  2022-09-29T03:00:00
# 14  Panic! At The Disco with Marina and Jake Wesle...  2022-10-01T03:00:00
# 15  Panic! At The Disco with Marina and Jake Wesle...  2022-10-02T03:00:00
# 16  Panic! At The Disco with Marina and Jake Wesle...  2022-10-03T03:00:00
# 17  Panic! At The Disco with Marina and Jake Wesle...  2022-10-05T03:00:00
# 18  Panic! At The Disco with Marina and Jake Wesle...  2022-10-06T03:00:00
# 19  Panic! At The Disco with Marina and Jake Wesle...  2022-10-08T03:00:00
# 20  Panic! At The Disco with Marina and Jake Wesle...  2022-10-09T04:00:00
# 21   Panic! At The Disco with Marina and Little Image  2022-10-10T04:00:00
# 22  Panic! At The Disco with Marina and Jake Wesle...  2022-10-12T05:00:00
# 23  Panic! At The Disco with Marina and Jake Wesle...  2022-10-14T05:00:00
# 24  Panic! At The Disco with Marina and Jake Wesle...  2022-10-16T06:00:00
#
#                                                 stats  \
# 0   {'listing_count': 1070, 'average_price': 291, ...
# 1   {'listing_count': 280, 'average_price': 319, '...
# 2   {'listing_count': 877, 'average_price': 270, '...
# 3   {'listing_count': 852, 'average_price': 261, '...
# 4   {'listing_count': 1168, 'average_price': 249, ...
# 5   {'listing_count': 1120, 'average_price': 255, ...
# 6   {'listing_count': 1475, 'average_price': 263, ...
# 7   {'listing_count': None, 'average_price': None,...
# 8   {'listing_count': 898, 'average_price': 253, '...
# 9   {'listing_count': 1193, 'average_price': 258, ...
# 10  {'listing_count': 740, 'average_price': 342, '...
# 11  {'listing_count': 1021, 'average_price': 270, ...
# 12  {'listing_count': 855, 'average_price': 230, '...
# 13  {'listing_count': 1223, 'average_price': 266, ...
# 14  {'listing_count': 276, 'average_price': 319, '...
# 15  {'listing_count': 1186, 'average_price': 284, ...
# 16  {'listing_count': 1176, 'average_price': 249, ...
# 17  {'listing_count': 1312, 'average_price': 254, ...
# 18  {'listing_count': 1204, 'average_price': 279, ...
# 19  {'listing_count': 143, 'average_price': 366, '...
# 20  {'listing_count': 1281, 'average_price': 252, ...
# 21  {'listing_count': 981, 'average_price': 251, '...
# 22  {'listing_count': 1090, 'average_price': 280, ...
# 23  {'listing_count': 1027, 'average_price': 242, ...
# 24  {'listing_count': 1418, 'average_price': 237, ...
#
#                                            taxonomies  \
# 0   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 1   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 2   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 3   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 4   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 5   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 6   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 7   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 8   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 9   [{'id': 2000000, 'name': 'concert', 'parent_id...
# 10  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 11  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 12  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 13  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 14  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 15  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 16  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 17  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 18  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 19  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 20  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 21  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 22  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 23  [{'id': 2000000, 'name': 'concert', 'parent_id...
# 24  [{'id': 2000000, 'name': 'concert', 'parent_id...
#
#                                                   url  score  \
# 0   https://seatgeek.com/panic-at-the-disco-with-b...  0.000
# 1   https://seatgeek.com/panic-at-the-disco-with-b...  0.744
# 2   https://seatgeek.com/panic-at-the-disco-with-b...  0.000
# 3   https://seatgeek.com/panic-at-the-disco-with-b...  0.699
# 4   https://seatgeek.com/panic-at-the-disco-with-b...  0.738
# 5   https://seatgeek.com/panic-at-the-disco-with-m...  0.000
# 6   https://seatgeek.com/panic-at-the-disco-with-m...  0.821
# 7   https://seatgeek.com/panic-at-the-disco-ticket...  0.715
# 8   https://seatgeek.com/panic-at-the-disco-with-m...  0.000
# 9   https://seatgeek.com/panic-at-the-disco-with-m...  0.728
# 10  https://seatgeek.com/panic-at-the-disco-with-m...  0.846
# 11  https://seatgeek.com/panic-at-the-disco-with-m...  0.752
# 12  https://seatgeek.com/panic-at-the-disco-with-m...  0.624
# 13  https://seatgeek.com/panic-at-the-disco-with-m...  0.795
# 14  https://seatgeek.com/panic-at-the-disco-with-m...  0.823
# 15  https://seatgeek.com/panic-at-the-disco-with-m...  0.804
# 16  https://seatgeek.com/panic-at-the-disco-with-m...  0.744
# 17  https://seatgeek.com/panic-at-the-disco-with-m...  0.784
# 18  https://seatgeek.com/panic-at-the-disco-with-m...  0.758
# 19  https://seatgeek.com/panic-at-the-disco-with-m...  0.767
# 20  https://seatgeek.com/panic-at-the-disco-with-m...  0.785
# 21  https://seatgeek.com/panic-at-the-disco-with-m...  0.757
# 22  https://seatgeek.com/panic-at-the-disco-with-m...  0.727
# 23  https://seatgeek.com/panic-at-the-disco-with-m...  0.698
# 24  https://seatgeek.com/panic-at-the-disco-with-m...  0.734
#
#     mobile_entry_enabled        announce_date           created_at  date_tbd  \
# 0                  False  2022-06-01T00:00:00  2022-06-01T15:57:36     False
# 1                  False  2022-06-01T00:00:00  2022-06-01T15:58:48     False
# 2                  False  2022-06-01T00:00:00  2022-06-01T15:59:43     False
# 3                  False  2022-06-01T00:00:00  2022-06-01T16:00:38     False
# 4                   True  2022-06-01T00:00:00  2022-06-01T16:01:32     False
# 5                  False  2022-06-01T00:00:00  2022-06-01T16:02:34     False
# 6                  False  2022-06-01T00:00:00  2022-06-01T16:03:25     False
# 7                  False  2022-07-23T00:00:00  2022-07-23T16:06:27     False
# 8                   True  2022-06-01T00:00:00  2022-06-01T16:04:24     False
# 9                  False  2022-06-01T00:00:00  2022-06-01T16:05:11     False
# 10                  True  2022-06-01T00:00:00  2022-06-01T16:06:00     False
# 11                  True  2022-06-01T00:00:00  2022-06-01T16:06:44     False
# 12                  True  2022-06-01T00:00:00  2022-06-01T16:07:42     False
# 13                  True  2022-06-01T00:00:00  2022-06-01T16:08:40     False
# 14                  True  2022-06-01T00:00:00  2022-06-01T16:09:32     False
# 15                  True  2022-06-01T00:00:00  2022-06-01T16:10:20     False
# 16                  True  2022-06-01T00:00:00  2022-06-01T16:11:04     False
# 17                  True  2022-06-01T00:00:00  2022-06-01T16:11:47     False
# 18                  True  2022-06-01T00:00:00  2022-06-01T16:12:20     False
# 19                 False  2022-06-01T00:00:00  2022-06-01T16:13:05     False
# 20                  True  2022-06-01T00:00:00  2022-06-01T16:14:06     False
# 21                  True  2022-06-01T00:00:00  2022-06-01T16:15:07     False
# 22                 False  2022-06-01T00:00:00  2022-06-01T16:16:07     False
# 23                 False  2022-06-01T00:00:00  2022-06-01T16:16:50     False
# 24                  True  2022-06-01T00:00:00  2022-06-01T16:17:27     False
#
#                                                 title  popularity description  \
# 0   Panic! At The Disco with Beach Bunny and Jake ...       0.000
# 1   Panic! At The Disco with Beach Bunny and Jake ...       0.839
# 2   Panic! At The Disco with Beach Bunny and Jake ...       0.000
# 3   Panic! At The Disco with Beach Bunny and Jake ...       0.814
# 4   Panic! At The Disco with Beach Bunny and Jake ...       0.838
# 5   Panic! At The Disco with Marina and Jake Wesle...       0.000
# 6   Panic! At The Disco with Marina and Jake Wesle...       0.883
# 7                                 Panic! At The Disco       0.859
# 8   Panic! At The Disco with Marina and Jake Wesle...       0.000
# 9   Panic! At The Disco with Marina and Jake Wesle...       0.827
# 10  Panic! At The Disco with Marina and Jake Wesle...       0.895
# 11  Panic! At The Disco with Marina and Jake Wesle...       0.838
# 12  Panic! At The Disco with Marina and Jake Wesle...       0.766
# 13  Panic! At The Disco with Marina and Jake Wesle...       0.864
# 14  Panic! At The Disco with Marina and Jake Wesle...       0.877
# 15  Panic! At The Disco with Marina and Jake Wesle...       0.865
# 16  Panic! At The Disco with Marina and Jake Wesle...       0.830
# 17  Panic! At The Disco with Marina and Jake Wesle...       0.853
# 18  Panic! At The Disco with Marina and Jake Wesle...       0.837
# 19  Panic! At The Disco with Marina and Jake Wesle...       0.842
# 20  Panic! At The Disco with Marina and Jake Wesle...       0.852
# 21   Panic! At The Disco with Marina and Little Image       0.835
# 22  Panic! At The Disco with Marina and Jake Wesle...       0.816
# 23  Panic! At The Disco with Marina and Jake Wesle...       0.801
# 24  Panic! At The Disco with Marina and Jake Wesle...       0.820
#
#     status                                      access_method event_promotion  \
# 0   normal                                               None            None
# 1   normal  {'method': 'NONE', 'created_at': '2015-11-30T1...            None
# 2   normal                                               None            None
# 3   normal  {'method': 'NONE', 'created_at': '2015-11-11T2...            None
# 4   normal  {'method': 'QRCODE_TM', 'created_at': '2015-08...            None
# 5   normal  {'method': 'NONE', 'created_at': '2019-03-28T1...            None
# 6   normal  {'method': 'NONE', 'created_at': '2016-10-20T1...            None
# 7   normal  {'method': 'NONE', 'created_at': '2016-10-20T1...            None
# 8   normal  {'method': 'QRCODE_TM', 'created_at': '2018-08...            None
# 9   normal  {'method': 'NONE', 'created_at': '2017-10-20T2...            None
# 10  normal  {'method': 'QRCODE_TM', 'created_at': '2017-10...            None
# 11  normal  {'method': 'QRCODE_TM', 'created_at': '2015-07...            None
# 12  normal  {'method': 'QRCODE', 'created_at': '2015-10-23...            None
# 13  normal  {'method': 'QRCODE_TM', 'created_at': '2015-07...            None
# 14  normal  {'method': 'QRCODE', 'created_at': '2017-11-04...            None
# 15  normal  {'method': 'QRCODE_TM', 'created_at': '2015-07...            None
# 16  normal  {'method': 'PDF417', 'created_at': '2018-11-17...            None
# 17  normal  {'method': 'QRCODE_TM', 'created_at': '2018-09...            None
# 18  normal  {'method': 'QRCODE_TM', 'created_at': '2015-10...            None
# 19  normal                                               None            None
# 20  normal  {'method': 'QRCODE_TM', 'created_at': '2015-07...            None
# 21  normal  {'method': 'QRCODE_TM', 'created_at': '2018-09...            None
# 22  normal  {'method': 'NONE', 'created_at': '2015-11-04T1...            None
# 23  normal  {'method': 'NONE', 'created_at': '2015-12-08T1...            None
# 24  normal  {'method': 'QRCODE_TM', 'created_at': '2015-08...            None
#
#                                         announcements  conditional  \
# 0                                                  {}        False
# 1                                                  {}        False
# 2                                                  {}        False
# 3                                                  {}        False
# 4                                                  {}        False
# 5                                                  {}        False
# 6                                                  {}        False
# 7                                                  {}        False
# 8                                                  {}        False
# 9                                                  {}        False
# 10  {'checkout_disclosures': {'messages': [{'text'...        False
# 11                                                 {}        False
# 12                                                 {}        False
# 13                                                 {}        False
# 14                                                 {}        False
# 15                                                 {}        False
# 16                                                 {}        False
# 17                                                 {}        False
# 18                                                 {}        False
# 19                                                 {}        False
# 20                                                 {}        False
# 21                                                 {}        False
# 22                                                 {}        False
# 23                                                 {}        False
# 24                                                 {}        False
#
#    enddatetime_utc last_valid_datetime_utc last_valid_datetime_local  \
# 0             None    2022-09-09T00:00:00Z      2022-09-08T19:00:00Z
# 1             None    2022-09-11T00:00:00Z      2022-09-10T19:00:00Z
# 2             None    2022-09-12T00:00:00Z      2022-09-11T19:00:00Z
# 3             None    2022-09-14T00:00:00Z      2022-09-13T19:00:00Z
# 4             None    2022-09-15T00:00:00Z      2022-09-14T19:00:00Z
# 5             None    2022-09-17T00:00:00Z      2022-09-16T19:00:00Z
# 6             None    2022-09-18T00:00:00Z      2022-09-17T19:00:00Z
# 7             None    2022-09-19T00:00:00Z      2022-09-18T19:00:00Z
# 8             None    2022-09-20T23:00:00Z      2022-09-20T19:00:00Z
# 9             None    2022-09-21T23:00:00Z      2022-09-21T19:00:00Z
# 10            None    2022-09-23T23:00:00Z      2022-09-23T19:00:00Z
# 11            None    2022-09-25T23:00:00Z      2022-09-25T19:00:00Z
# 12            None    2022-09-27T23:00:00Z      2022-09-27T19:00:00Z
# 13            None    2022-09-28T23:00:00Z      2022-09-28T19:00:00Z
# 14            None    2022-09-30T23:00:00Z      2022-09-30T19:00:00Z
# 15            None    2022-10-01T23:00:00Z      2022-10-01T19:00:00Z
# 16            None    2022-10-02T23:00:00Z      2022-10-02T19:00:00Z
# 17            None    2022-10-04T23:00:00Z      2022-10-04T19:00:00Z
# 18            None    2022-10-05T23:00:00Z      2022-10-05T19:00:00Z
# 19            None    2022-10-07T23:00:00Z      2022-10-07T19:00:00Z
# 20            None    2022-10-09T00:00:00Z      2022-10-08T19:00:00Z
# 21            None    2022-10-10T00:00:00Z      2022-10-09T19:00:00Z
# 22            None    2022-10-12T01:00:00Z      2022-10-11T19:00:00Z
# 23            None    2022-10-14T01:00:00Z      2022-10-13T19:00:00Z
# 24            None    2022-10-16T02:00:00Z      2022-10-15T19:00:00Z
#
#             schedule_status  \
# 0   as_originally_scheduled
# 1   as_originally_scheduled
# 2   as_originally_scheduled
# 3   as_originally_scheduled
# 4   as_originally_scheduled
# 5   as_originally_scheduled
# 6   as_originally_scheduled
# 7   as_originally_scheduled
# 8   as_originally_scheduled
# 9   as_originally_scheduled
# 10  as_originally_scheduled
# 11  as_originally_scheduled
# 12  as_originally_scheduled
# 13  as_originally_scheduled
# 14  as_originally_scheduled
# 15  as_originally_scheduled
# 16  as_originally_scheduled
# 17  as_originally_scheduled
# 18  as_originally_scheduled
# 19  as_originally_scheduled
# 20  as_originally_scheduled
# 21  as_originally_scheduled
# 22  as_originally_scheduled
# 23  as_originally_scheduled
# 24  as_originally_scheduled
#
#                                                   map  \
# 0   {'id': 'v518721-10776-2', 'retina_id': 'v51872...
# 1   {'id': 'v129-6949-3', 'retina_id': 'v129-6949-...
# 2   {'id': 'v460055-10797-1', 'retina_id': 'v46005...
# 3   {'id': 'v84-3796-4', 'retina_id': 'v84-3796-4....
# 4   {'id': 'v123-7001-2', 'retina_id': 'v123-7001-...
# 5   {'id': 'v435592-6734-5', 'retina_id': 'v435592...
# 6   {'id': 'v136-6110-4', 'retina_id': 'v136-6110-...
# 7   {'id': 'v136-6110-4', 'retina_id': 'v136-6110-...
# 8   {'id': 'v420444-6138-5', 'retina_id': 'v420444...
# 9   {'id': 'v430-10800-1', 'retina_id': 'v430-1080...
# 10  {'id': 'v93-10773-2', 'retina_id': 'v93-10773-...
# 11  {'id': 'v91-3469-5', 'retina_id': 'v91-3469-5....
# 12  {'id': 'v139-6042-5', 'retina_id': 'v139-6042-...
# 13  {'id': 'v1544-4968-3', 'retina_id': 'v1544-496...
# 14  {'id': 'v3148-5948-2', 'retina_id': 'v3148-594...
# 15  {'id': 'v181-5298-3', 'retina_id': 'v181-5298-...
# 16  {'id': 'v1430-6806-3', 'retina_id': 'v1430-680...
# 17  {'id': 'v126-6109-5', 'retina_id': 'v126-6109-...
# 18  {'id': 'v182-5207-2', 'retina_id': 'v182-5207-...
# 19  {'id': 'v110-10803-1', 'retina_id': 'v110-1080...
# 20  {'id': 'v2195-6394-3', 'retina_id': 'v2195-639...
# 21  {'id': 'v186-7021-5', 'retina_id': 'v186-7021-...
# 22  {'id': 'v187-10779-1', 'retina_id': 'v187-1077...
# 23  {'id': 'v188-10804-1', 'retina_id': 'v188-1080...
# 24  {'id': 'v256-4433-4', 'retina_id': 'v256-4433-...
#
#                                          relative_url  is_hybrid  \
# 0   /panic-at-the-disco-with-beach-bunny-and-jake-...       True
# 1   /panic-at-the-disco-with-beach-bunny-and-jake-...       True
# 2   /panic-at-the-disco-with-beach-bunny-and-jake-...       True
# 3   /panic-at-the-disco-with-beach-bunny-and-jake-...       True
# 4   /panic-at-the-disco-with-beach-bunny-and-jake-...       True
# 5   /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 6   /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 7   /panic-at-the-disco-tickets/chicago-illinois-u...       True
# 8   /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 9   /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 10  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 11  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 12  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 13  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 14  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 15  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 16  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 17  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 18  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 19  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 20  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 21  /panic-at-the-disco-with-marina-and-little-ima...       True
# 22  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 23  /panic-at-the-disco-with-marina-and-jake-wesle...       True
# 24  /panic-at-the-disco-with-marina-and-jake-wesle...       True
#
#     show_static_map_images themes domain_information
# 0                     True     []                 []
# 1                     True     []                 []
# 2                     True     []                 []
# 3                     True     []                 []
# 4                     True     []                 []
# 5                     True     []                 []
# 6                     True     []                 []
# 7                     True     []                 []
# 8                     True     []                 []
# 9                     True     []                 []
# 10                    True     []                 []
# 11                    True     []                 []
# 12                    True     []                 []
# 13                    True     []                 []
# 14                    True     []                 []
# 15                    True     []                 []
# 16                    True     []                 []
# 17                    True     []                 []
# 18                    True     []                 []
# 19                    True     []                 []
# 20                    True     []                 []
# 21                    True     []                 []
# 22                    True     []                 []
# 23                    True     []                 []
# 24                    True     []                 []
